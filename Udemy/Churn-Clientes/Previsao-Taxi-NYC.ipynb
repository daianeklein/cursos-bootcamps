# %% [markdown]
# # BIBLIOTECAS

# %%
import pandas as pd 
import numpy as np

from sklearn.ensemble import ExtraTreesClassifier, RandomForestClassifier, GradientBoostingClassifier
import matplotlib.pyplot as plt

from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# # DATASETS

# %%
features = pd.read_csv(r'/Users/daianeklein/Documents/Cursos/cursos-bootcamps/Udemy/Previsão corridas NYC/kdd/orange_small_test.data',
                      sep='\t', na_filter=False, engine='python')

features.head(3)
# Out:
#       Var1 Var2 Var3 Var4 Var5  Var6 Var7 Var8 Var9 Var10  ...   Var221  \
# 0                               1225    7                  ...  Al6ZaUT
# 1                                259    0                  ...     oslk
# 2                                861   14                  ...     oslk
# 3                               1568    7                  ...     oslk
# 4                               1197    7                  ...  Al6ZaUT
# ...    ...  ...  ...  ...  ...   ...  ...  ...  ...   ...  ...      ...
# 49995                           3367    7                  ...  QKW8DRm
# 49996                            182    0                  ...  d0EEeJi
# 49997                            525    0                  ...     oslk
# 49998                           1582   21                  ...     oslk
# 49999                            112    0                  ...     oslk
#
#         Var222      Var223 Var224 Var225 Var226   Var227               Var228  \
# ...

# %%
outcome = pd.read_csv(r'/Users/daianeklein/Documents/Cursos/cursos-bootcamps/Udemy/Previsão corridas NYC/kdd/orange_small_train_churn.labels',
                     header=None)

outcome.head(3)
# Out:
#    0
# 0 -1
# 1  1
# 2 -1

# %% [markdown]
# ## IDENTIFICANDO VARIAVEIS NUMERICAS E CATEGORICAS

# %%
#todas as variaveis
all_vars = np.array(features.columns)

#Variaveis numericas
num_vars = np.array(all_vars[:190])

#Variaveis categoricas
cat_vars = np.array(all_vars[190:])

# %% [markdown]
# ## TIPO DE DADOS

# %%
features.dtypes
# Out:
# Var1      object
# Var2      object
# Var3      object
# Var4      object
# Var5      object
#            ...
# Var226    object
# Var227    object
# Var228    object
# Var229    object
# Var230    object
# Length: 230, dtype: object

# %%
var = features.groupby('Var1').size()
var
# Out:
# Var1
#         49312
# 0         367
# 104         1
# 120         1
# 1288        1
# 16         73
# 168         1
# 24         39
# 248         1
# 32         26
# 352         1
# 40          9
# 48         10
# 56          4
# 64          2
# 72          4
# 8         145
# 80          3
# dtype: int64

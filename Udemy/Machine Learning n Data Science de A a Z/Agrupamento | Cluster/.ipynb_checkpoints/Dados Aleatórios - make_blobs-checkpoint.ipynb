# %% [markdown]
# ## <font color=RoyalBlue size=5>Curso Machine Learning n Data Science de A à Z</font>
#
# ***

# %% [markdown]
# #### <font color=CornflowerBlue size=4>Seçao 20 - Agrupamento KMeans</font>
# <font color=CornflowerBlue size=3> Testando algoritmo de agrupamento</font>
# ***

# %%
## Importando as bibliotecas

import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs

# %% [markdown]
# #### <font color=CornflowerBlue size=4>Criando dados aleatórios</font>
#
# ***

# %%
## Definindo a quantidade de dados e a quantidade de 'centros'
x, y = make_blobs(n_samples = 200, centers = 4) 


## Plotando
plt.scatter(x[:,0], x[:,1])

# %%
## Treinando

kmeans = KMeans(n_clusters = 4)
kmeans.fit(x)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=4, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
## Similar à classificacao, fazendo as previsoes
previsoes = kmeans.predict(x)
plt.scatter(x[:,0], x[:,1], c = previsoes)

# %% [markdown]
# # Dados do Metrô

# %%
# %matplotlib inline
import geopandas as gpd
import pandas as pd

# %%
metro = gpd.read_file('../01.Dados/Transporte/Metro/Estacao_Metro.geojson')

# %%
metro
# Out:
#     OBJECTID  Cod                      Nome  Flg_ATM  Flg_Bicicletario  \
# 0          1    1                    Pavuna        1               1.0
# 1          2    2   Engenheiro Rubens Paiva        1               1.0
# 2          3    3  Acari / Fazenda Botafogo        0               0.0
# 3          4    4               Coelho Neto        1               0.0
# 4          5    5                   Colégio        1               1.0
# 5          6    6                     Irajá        1               1.0
# 6          7    7       Vicente de Carvalho        1               1.0
# 7          8    8              Tomaz Coelho        0               0.0
# 8          9    9         Engenho da Rainha        1               0.0
# 9         10   10                   Inhauma        1               1.0
# 10        11   11              Del Castilho        1               0.0
# 11        12   12            Maria da Graça        1               0.0
# 12        13   13                   Triagem        1               1.0
# 13        14   14                  Maracanã        1               0.0
# 14        15   15             São Cristóvão        1               0.0
# 15        16   16                   Estácio        1               1.0
# 16        17   17                Saens Peña        1               0.0
# 17        18   18      São Francisco Xavier        1               1.0
# 18        19   19               Afonso Pena        1               0.0
# 19        20   21                   Central        1               0.0
# 20        21   22         Presidente Vargas        1               0.0
# 21        22   23                Uruguaiana        1               0.0
# 22        23   24                   Carioca        1               0.0
# 23        24   25                Cinelândia        1               0.0
# 24        25   26                    Glória        1               1.0
# 25        26   27                    Catete        1               1.0
# 26        27   28          Largo do Machado        1               0.0
# 27        28   29                  Flamengo        1               0.0
# 28        29   30                  Botafogo        1               0.0
# 29        30   31         Cardeal Arcoverde        1               0.0
# 30        31   32           Siqueira Campos        1               1.0
# 31        32   33                Praca Onze        1               0.0
# 32        33   34                 Cantagalo        1               1.0
# 33        34   35               Cidade Nova        1               0.0
# 34        35   36  Ipanema / General Osório        1               1.0
# 35        36   37                   Uruguai        0               1.0
# 36        37   38      Nossa Senhora da Paz        1               NaN
# 37        38   39            Jardim de Alah        1               NaN
# 38        39   40         Antero de Quental        1               NaN
# 39        40   41               São Conrado        1               NaN
# 40        41   42           Jardim Oceânico        1               NaN
#
#     Flg_Elevador  Flg_Linha1  Flg_Linha2  \
# 0            1.0           0           1
# 1            1.0           0           1
# 2            0.0           0           1
# 3            0.0           0           1
# 4            0.0           0           1
# 5            1.0           0           1
# 6            0.0           0           1
# 7            1.0           0           1
# 8            0.0           0           1
# 9            1.0           0           1
# 10           1.0           0           1
# 11           0.0           0           1
# 12           0.0           0           1
# 13           0.0           0           1
# 14           0.0           0           1
# 15           1.0           1           0
# 16           1.0           1           0
# 17           0.0           1           0
# 18           0.0           1           0
# 19           0.0           1           1
# 20           0.0           1           1
# 21           0.0           1           1
# 22           1.0           1           1
# 23           0.0           1           1
# 24           0.0           1           1
# 25           0.0           1           1
# 26           1.0           1           1
# 27           1.0           1           1
# 28           1.0           1           1
# 29           0.0           1           0
# 30           0.0           1           0
# 31           0.0           1           0
# 32           1.0           1           0
# 33           1.0           0           1
# 34           0.0           1           0
# 35           0.0           1           0
# 36           1.0           0           0
# 37           1.0           0           0
# 38           1.0           0           0
# 39           NaN           0           0
# 40           1.0           0           0
#
#                                                Obs  Flg_Ativa  ...  \
# 0                                             None          1  ...
# 1                                             None          1  ...
# 2                                             None          1  ...
# 3                                             None          1  ...
# 4                                             None          1  ...
# 5                                             None          1  ...
# 6                                             None          1  ...
# 7                                             None          1  ...
# 8                                             None          1  ...
# 9                                             None          1  ...
# 10                                            None          1  ...
# 11                                            None          1  ...
# 12                                            None          1  ...
# 13                                            None          1  ...
# 14                                            None          1  ...
# 15  Estação de transferência para linha 2 do metrô          1  ...
# 16                                            None          1  ...
# 17                                            None          1  ...
# 18                                            None          1  ...
# 19                 Estação com Posto de Gratuidade          1  ...
# 20                                            None          1  ...
# 21                                            None          1  ...
# 22                  Estação com Achados e Perdidos          1  ...
# 23                                            None          1  ...
# 24                                            None          1  ...
# 25                                            None          1  ...
# 26                                            None          1  ...
# 27                                            None          1  ...
# 28                                            None          1  ...
# 29                                            None          1  ...
# 30                                            None          1  ...
# 31                                            None          1  ...
# 32                                            None          1  ...
# 33                                            None          1  ...
# 34                                            None          1  ...
# 35                                            None          1  ...
# 36                                    Nova Linha 4          1  ...
# 37                                    Nova Linha 4          1  ...
# 38                                    Nova Linha 4          1  ...
# 39                                    Nova Linha 4          1  ...
# 40                                    Nova Linha 4          1  ...
#
#    Integra_Trem Integra_Onibus  Integra_BRT      Corredor  Integra_VLT  \
# 0             1              0            0          None            0
# 1             0              0            0          None            0
# 2             0              0            0          None            0
# 3             0              0            0          None            0
# 4             0              0            0          None            0
# 5             0              0            0          None            0
# 6             0              0            1  Transcarioca            0
# 7             0              0            0          None            0
# 8             0              0            0          None            0
# 9             0              0            0          None            0
# 10            0              1            0          None            0
# 11            0              0            0          None            0
# 12            1              0            0          None            0
# 13            1              0            0          None            0
# 14            1              0            0          None            0
# 15            0              1            0          None            0
# 16            0              1            0          None            0
# 17            0              1            0          None            0
# 18            0              0            0          None            0
# 19            1              0            0          None            0
# 20            0              0            0          None            0
# 21            0              0            0          None            0
# 22            0              0            0          None            1
# 23            0              0            0          None            1
# 24            0              0            0          None            0
# 25            0              0            0          None            0
# 26            0              1            0          None            0
# 27            0              0            0          None            0
# 28            0              1            0          None            0
# 29            0              0            0          None            0
# 30            0              0            0          None            0
# 31            0              0            0          None            0
# 32            0              0            0          None            0
# 33            0              0            0          None            0
# 34            0              0            0          None            0
# 35            0              0            0          None            0
# 36            0              0            0          None            0
# 37            0              0            0          None            0
# 38            0              0            0          None            0
# 39            0              0            0          None            0
# 40            0              0            1    Transoeste            0
#
#                                   Onibus Flg_Metro_Superficie  \
# 0                                   None                    0
# 1                                   None                    0
# 2                                   None                    0
# 3                                   None                    0
# 4                                   None                    0
# 5                                   None                    0
# 6                                   None                    0
# 7                                   None                    0
# 8                                   None                    0
# 9                                   None                    0
# 10            Fundão, Jacarepaguá, Barra                    0
# 11                                  None                    0
# 12                                  None                    0
# 13                                  None                    0
# 14                                  None                    0
# 15                      Caju, Rodoviária                    0
# 16          Usina, Muda, Grajaú, Andaraí                    0
# 17                    Vila Isabel, Méier                    0
# 18                                  None                    0
# 19                                  None                    0
# 20                                  None                    0
# 21                                  None                    0
# 22                                  None                    0
# 23                                  None                    0
# 24                                  None                    0
# 25                                  None                    0
# 26  Laranjeiras, Cosme Velho, Rodoviária                    0
# 27                                  None                    0
# 28                                  Urca                    1
# 29                                  None                    0
# 30                                  None                    0
# 31                                  None                    0
# 32                                  None                    0
# 33                                  None                    0
# 34                                  None                    1
# 35                                  None                    0
# 36                                  None                    0
# 37                                  None                    0
# 38                                  None                    0
# 39                                  None                    0
# 40                                  None                    0
#
#     Metro_Superficie Data_Inauguracao                     geometry
# 0               None             1998  POINT (-43.36485 -22.80662)
# 1               None             1998  POINT (-43.35845 -22.81627)
# 2               None             1998  POINT (-43.34964 -22.82452)
# 3               None             1998  POINT (-43.34326 -22.83148)
# 4               None             1998  POINT (-43.33386 -22.84269)
# 5               None             1998  POINT (-43.32329 -22.84795)
# 6               None             1996  POINT (-43.31306 -22.85406)
# 7               None             1996  POINT (-43.30676 -22.86240)
# 8               None             1991  POINT (-43.29741 -22.86785)
# 9               None             1983  POINT (-43.28337 -22.87456)
# 10              None             1983  POINT (-43.27185 -22.87929)
# 11              None             1983  POINT (-43.26028 -22.88154)
# 12              None             1988  POINT (-43.24433 -22.89695)
# 13              None             1981  POINT (-43.23387 -22.90974)
# 14              None             1981  POINT (-43.22191 -22.90971)
# 15              None             1980  POINT (-43.20659 -22.91338)
# 16              None             1982  POINT (-43.23230 -22.92397)
# 17              None             1982  POINT (-43.22389 -22.92051)
# 18              None             1982  POINT (-43.21805 -22.91799)
# 19              None             1979  POINT (-43.19158 -22.90471)
# 20              None             1979  POINT (-43.18612 -22.90322)
# 21              None             1980  POINT (-43.18147 -22.90333)
# 22              None             1981  POINT (-43.17755 -22.90734)
# 23              None             1979  POINT (-43.17535 -22.91160)
# 24              None             1979  POINT (-43.17674 -22.91998)
# 25              None             1981  POINT (-43.17662 -22.92587)
# 26              None             1981  POINT (-43.17780 -22.93113)
# 27              None             1981  POINT (-43.17894 -22.93762)
# 28             Gávea             1981  POINT (-43.18384 -22.95120)
# 29              None             1998  POINT (-43.18095 -22.96459)
# 30              None             2003  POINT (-43.18663 -22.96717)
# 31              None             1979  POINT (-43.20027 -22.90990)
# 32              None             2007  POINT (-43.19382 -22.97667)
# 33              None             2009  POINT (-43.20623 -22.90875)
# 34             Gávea             2009  POINT (-43.19714 -22.98476)
# 35              None             2014  POINT (-43.23973 -22.93157)
# 36              None             2016  POINT (-43.20681 -22.98380)
# 37              None             2016  POINT (-43.21463 -22.98283)
# 38              None             2016  POINT (-43.22320 -22.98509)
# 39              None             2016  POINT (-43.25400 -22.99212)
# 40              None             2016  POINT (-43.31090 -23.00679)
#
# [41 rows x 23 columns]

# %%
metro.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
metro = metro.to_crs('+proj=utm +zone=23 +south +ellps=GRS80 +towgs84=0,0,0,0,0,0,0 +units=km +no_defs')

# %%
metro.crs
# Out:
# <Bound CRS: +proj=utm +zone=23 +south +ellps=GRS80 +towgs84=0, ...>
# Name: unknown
# Axis Info [cartesian]:
# - E[east]: Easting (kilometre)
# - N[north]: Northing (kilometre)
# Area of Use:
# - undefined
# Coordinate Operation:
# - name: Transformation from unknown to WGS84
# - method: Position Vector transformation (geog2D domain)
# Datum: Unknown based on GRS80 ellipsoid
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich
# Source CRS: unknown

# %%
rj = gpd.read_file('../01.Dados/Mapas/RJ-MUNIC/RJ-MUNIC.shp')
geo_dados = gpd.read_file('../01.Dados/Mapas/RJ-DATASET/DATASET.shp')

# %% [markdown]
# # AGREGANDO OUTROS TIPOS DE TRANSPORTES

# %% [markdown]
# ## Estações de Trem

# %%
trem = gpd.read_file('../01.Dados/Transporte/Trem/Estações_Trem.geojson')

# %%
trem
# Out:
#      OBJECTID  Cod                    Nome  Flg_IntegraOnibus  \
# 0           1   60             Nova Iguaçu                NaN
# 1           2   20       Comendador Soares                NaN
# 2           3    4                  Austin                NaN
# 3           4   81               Queimados                NaN
# 4           5   29     Engenheiro Pedreira                NaN
# ..        ...  ...                     ...                ...
# 99        100   59               Nilópolis                NaN
# 100       101   57                Mesquita                NaN
# 101       102   62                  Olinda                NaN
# 102       103   86  Ricardo de Albuquerque                NaN
# 103       104   80    Presidente Juscelino                NaN
#
#      Flg_IntegraMetro  Flg_Terminal  Flg_TransfRamal  Flg_TransfCentral  \
# 0                 NaN           1.0              NaN                NaN
# 1                 NaN           NaN              NaN                NaN
# 2                 NaN           NaN              NaN                NaN
# 3                 NaN           1.0              NaN                NaN
# 4                 NaN           NaN              NaN                NaN
# ..                ...           ...              ...                ...
# 99                NaN           NaN              NaN                NaN
# 100               NaN           NaN              NaN                NaN
# 101               NaN           NaN              NaN                NaN
# 102               NaN           NaN              NaN                NaN
# 103               NaN           NaN              NaN                NaN
#
#      Flg_IntegraTele  Flg_Mun  ...  Flg_Deodoro  Flg_SantaCruz  Flg_Japeri  \
# 0                NaN      0.0  ...          NaN            NaN         1.0
# 1                NaN      0.0  ...          NaN            NaN         1.0
# 2                NaN      0.0  ...          NaN            NaN         1.0
# 3                NaN      0.0  ...          NaN            NaN         1.0
# 4                NaN      0.0  ...          NaN            NaN         1.0
# ..               ...      ...  ...          ...            ...         ...
# 99               NaN      NaN  ...          NaN            NaN         1.0
# 100              NaN      NaN  ...          NaN            NaN         1.0
# 101              NaN      NaN  ...          NaN            NaN         1.0
# 102              NaN      1.0  ...          NaN            NaN         1.0
# 103              NaN      NaN  ...          NaN            NaN         1.0
#
#      Flg_Paracambi  Flg_VilaInhomirim  Flg_Guapimirim  Data_Inc  Integra_BRT  \
# 0              NaN                NaN             NaN      None          NaN
# 1              NaN                NaN             NaN      None          NaN
# 2              NaN                NaN             NaN      None          NaN
# 3              NaN                NaN             NaN      None          NaN
# 4              NaN                NaN             NaN      None          NaN
# ..             ...                ...             ...       ...          ...
# 99             NaN                NaN             NaN      None          NaN
# 100            NaN                NaN             NaN      None          NaN
# 101            NaN                NaN             NaN      None          NaN
# 102            NaN                NaN             NaN      None          NaN
# 103            NaN                NaN             NaN      None          NaN
#
#      Corredor_BRT                     geometry
# 0            None  POINT (-43.44939 -22.76073)
# 1            None  POINT (-43.48895 -22.74415)
# 2            None  POINT (-43.52271 -22.72031)
# 3            None  POINT (-43.55610 -22.71624)
# 4            None  POINT (-43.60606 -22.67875)
# ..            ...                          ...
# 99           None  POINT (-43.41466 -22.80921)
# 100          None  POINT (-43.42859 -22.78255)
# 101          None  POINT (-43.40996 -22.81740)
# 102          None  POINT (-43.39821 -22.83965)
# 103          None  POINT (-43.43414 -22.77032)
#
# [104 rows x 24 columns]

# %%
trem = trem.to_crs('+proj=utm +zone=23 +south +ellps=GRS80 +towgs84=0,0,0,0,0,0,0 +units=km +no_defs')

# %%
base = rj.plot(color = 'white', edgecolor = 'black', figsize=(15, 8))
geo_dados.plot(ax=base, color = 'orange', alpha = 0.2)
metro.plot(ax=base, color = 'black', markersize=80)
trem.plot(ax=base, color = 'red')
# Out:
# <AxesSubplot:>

# %%
# removendo os pontos que estão fora do mapa do RJ

trem = trem[trem.within(rj.iloc[0].geometry)]

# %%
base = rj.plot(color = 'white', edgecolor = 'black', figsize=(15, 8))
geo_dados.plot(ax=base, color = 'orange', alpha = 0.2)
metro.plot(ax=base, color = 'black', markersize=80)
trem.plot(ax=base, color = 'red')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Estações BRT

# %%
brt = gpd.read_file('../01.Dados/Transporte/BRT/Estações_BRT.geojson')

# %%
brt
# Out:
#      OBJECTID                              Nome  Flg_Ativo  Status  \
# 0           1                       Santa Luzia          1       1
# 1           2                              Maré          1       1
# 2           3  Cardoso de Moraes - Viúva Garcia          1       1
# 3           4                           Penha I          1       1
# 4           5                          Penha II          1       1
# ..        ...                               ...        ...     ...
# 156       158               Marechal Fontenelle          1       1
# 157       159                   Marechal Mallet          1       1
# 158       160                  Magalhães Bastos          1       1
# 159       161                      Vila Militar          1       1
# 160       163                  Terminal Sulacap          1       1
#
#                X             Y  Flg_TransCarioca  Flg_TransBrasil  \
# 0    679342.4694  7.471500e+06                 1                0
# 1    680236.1565  7.472380e+06                 1                0
# 2    678744.0560  7.471252e+06                 1                0
# 3    676833.5642  7.473029e+06                 1                0
# 4    676873.5062  7.472977e+06                 1                0
# ..           ...           ...               ...              ...
# 156  664095.9896  7.468251e+06                 0                0
# 157  663615.1812  7.469374e+06                 0                0
# 158  662717.0295  7.470178e+06                 0                0
# 159  664022.2312  7.470841e+06                 0                0
# 160  664220.4598  7.468442e+06                 0                0
#
#      Flg_TransOeste  Flg_TransOlimpica ChaveGeo Data_Inc  Integra_Trem  \
# 0                 0                  0     None     None           0.0
# 1                 0                  0     None     None           0.0
# 2                 0                  0     None     None           0.0
# 3                 0                  0     None     None           0.0
# 4                 0                  0     None     None           0.0
# ..              ...                ...      ...      ...           ...
# 156               0                  1     None     None           0.0
# 157               0                  1     None     None           0.0
# 158               0                  1     None     None           0.0
# 159               0                  1     None     None           1.0
# 160               0                  1     None     None           0.0
#
#      Integra_Metro  Integra_Aeroporto                     geometry
# 0              0.0                0.0  POINT (-43.25244 -22.85513)
# 1              0.0                0.0  POINT (-43.24383 -22.84709)
# 2              0.0                0.0  POINT (-43.25824 -22.85743)
# 3              0.0                0.0  POINT (-43.27706 -22.84158)
# 4              0.0                0.0  POINT (-43.27666 -22.84205)
# ..             ...                ...                          ...
# 156            0.0                0.0  POINT (-43.40065 -22.88602)
# 157            0.0                0.0  POINT (-43.40545 -22.87593)
# 158            0.0                0.0  POINT (-43.41429 -22.86876)
# 159            0.0                0.0  POINT (-43.40164 -22.86265)
# 160            0.0                0.0  POINT (-43.39945 -22.88429)
#
# [161 rows x 16 columns]

# %%
brt.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
brt = brt.to_crs('+proj=utm +zone=23 +south +ellps=GRS80 +towgs84=0,0,0,0,0,0,0 +units=km +no_defs')

# %%
brt.crs
# Out:
# <Bound CRS: +proj=utm +zone=23 +south +ellps=GRS80 +towgs84=0, ...>
# Name: unknown
# Axis Info [cartesian]:
# - E[east]: Easting (kilometre)
# - N[north]: Northing (kilometre)
# Area of Use:
# - undefined
# Coordinate Operation:
# - name: Transformation from unknown to WGS84
# - method: Position Vector transformation (geog2D domain)
# Datum: Unknown based on GRS80 ellipsoid
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich
# Source CRS: unknown

# %%
base = rj.plot(color = 'white', edgecolor = 'black', figsize=(15, 8))
geo_dados.plot(ax=base, color = 'orange', alpha = 0.2)
metro.plot(ax=base, color = 'black', markersize=80)
trem.plot(ax=base, color = 'red', markersize=80)
brt.plot(ax=base, color = 'blue', markersize=80)
# Out:
# <AxesSubplot:>

# %%
transporte = pd.concat([trem.geometry, metro.geometry, brt.geometry], ignore_index=True)
transporte
# Out:
# 0      POINT (676.866 7466.079)
# 1      POINT (663.964 7470.815)
# 2      POINT (662.792 7470.218)
# 3      POINT (661.119 7469.485)
# 4      POINT (659.274 7469.469)
#                  ...
# 257    POINT (664.056 7468.207)
# 258    POINT (663.576 7469.330)
# 259    POINT (662.677 7470.133)
# 260    POINT (663.983 7470.796)
# 261    POINT (664.181 7468.397)
# Length: 262, dtype: geometry

# %%
type(transporte)
# Out:
# geopandas.geoseries.GeoSeries

# %%
geo_dados['Dist_Transporte'] = geo_dados['geometry'].apply(lambda x: transporte.distance(x).min())

# %%
geo_dados.corr()
# Out:
#                      Area  Latitude  Longitude   Quartos    Suites     Vagas  \
# Area             1.000000 -0.289299   0.029982  0.681112  0.585817  0.594699
# Latitude        -0.289299  1.000000   0.292822 -0.225226 -0.346480 -0.274707
# Longitude        0.029982  0.292822   1.000000 -0.016882 -0.221548 -0.283960
# Quartos          0.681112 -0.225226  -0.016882  1.000000  0.529611  0.520499
# Suites           0.585817 -0.346480  -0.221548  0.529611  1.000000  0.621140
# Vagas            0.594699 -0.274707  -0.283960  0.520499  0.621140  1.000000
# Valor            0.724397 -0.299038   0.191868  0.481216  0.464075  0.456596
# Dist_Metro      -0.036671 -0.217864  -0.874788  0.021794  0.188521  0.215787
# Dist_Transporte -0.042684  0.358735  -0.031812 -0.014628  0.006363  0.070240
#
#                     Valor  Dist_Metro  Dist_Transporte
# Area             0.724397   -0.036671        -0.042684
# Latitude        -0.299038   -0.217864         0.358735
# Longitude        0.191868   -0.874788        -0.031812
# Quartos          0.481216    0.021794        -0.014628
# Suites           0.464075    0.188521         0.006363
# Vagas            0.456596    0.215787         0.070240
# Valor            1.000000   -0.195641        -0.103653
# Dist_Metro      -0.195641    1.000000         0.261040
# Dist_Transporte -0.103653    0.261040         1.000000

# %%
geo_dados.to_file('../01.Dados/Mapas/RJ-DATASET/DATASET.shp')
